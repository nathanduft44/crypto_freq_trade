# %%
import pandas as pd
from pathlib import Path

# %%
dataframe_final_2020_2021_df = pd.read_csv("final_df_2020_2021.csv")
dataframe_final_2020_2021_df
# Out:
#      Unnamed: 0  asset_id        time          open         close  \
# 0             0         1  2020-11-15  15802.187190  15948.282981
# 1             1         1  2020-11-16  16152.833879  16681.218303
# 2             2         1  2020-11-17  17030.739791  17669.369095
# 3             3         1  2020-11-18  17601.221560  17815.231510
# 4             4         1  2020-11-19  17789.906546  17891.053796
# ..          ...       ...         ...           ...           ...
# 325         325         1  2021-10-06  51579.810426  55432.144772
# 326         326         1  2021-10-07  55398.722582  53886.548908
# 327         327         1  2021-10-08  53897.669283  54110.345375
# 328         328         1  2021-10-09  54139.628108  55117.938981
# 329         329         1  2021-10-10  55112.465820  54880.211790
#
#              high           low        volume    market_cap  reddit_posts  \
# 0    15948.282981  15802.187190  2.010812e+10  2.966502e+11        1059.0
# ...
