# %%
import pandas as pd
from pathlib import Path

# %%
dataframe_final_df = pd.read_csv("final_df.csv")

# %%
dataframe_final_df
# Out:
#      Unnamed: 0  asset_id        time          open         close  \
# 0             0         1  2018-12-16   3220.650000   3223.930000
# 1             1         1  2018-12-17   3254.900000   3511.870000
# 2             2         1  2018-12-18   3555.300000   3678.780000
# 3             3         1  2018-12-19   3673.900000   3685.200000
# 4             4         1  2018-12-20   3740.520000   4086.320000
# ..          ...       ...         ...           ...           ...
# 695         695         1  2020-11-10  15448.221157  15336.218368
# 696         696         1  2020-11-11  15566.280070  15724.802451
# 697         697         1  2020-11-12  15700.956633  16285.182626
# 698         698         1  2020-11-13  16544.819664  16330.095809
# 699         699         1  2020-11-14  16030.256051  16081.263470
#
#              high           low       volume    market_cap  reddit_posts  ...  \
# 0     3273.300000   3217.250000    853624611  5.618165e+10         151.0  ...
# ...
