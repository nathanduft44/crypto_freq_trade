# %%
import pandas as pd
from pathlib import Path

# %%
dataframe_final_df = pd.read_csv("final_df.csv")

# %%
dataframe_final_df
# Out:
#                              open         close          high           low  \
# time
# 2021-10-05 00:00:00  49291.614867  49580.869981  49836.387190  49137.142925
# 2021-10-05 01:00:00  49578.481326  49319.445243  49617.550634  49263.197503
# 2021-10-05 02:00:00  49330.907134  49418.877472  49450.576022  49198.099169
# 2021-10-05 03:00:00  49419.776938  49400.596326  49557.142736  49267.414247
# 2021-10-05 04:00:00  49397.449653  49268.924604  49397.449653  49204.091696
# ...                           ...           ...           ...           ...
# 2021-10-09 01:00:00  54450.750262  54191.446186  54450.750262  54068.662813
# 2021-10-09 02:00:00  54170.024854  54310.918467  54329.361078  54058.349692
# 2021-10-09 03:00:00  54324.940919  54728.311716  54835.588983  54324.940919
# 2021-10-09 04:00:00  54717.991674  54840.329458  54868.369286  54686.876502
# 2021-10-09 05:00:00  54741.380509  54616.528289  54757.485239  54511.997852
#
# ...
