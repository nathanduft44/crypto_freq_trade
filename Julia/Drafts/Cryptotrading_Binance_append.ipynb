# %%
import pandas as pd
import sqlalchemy
from binance.client import Client
from binance import BinanceSocketManager
import os

# %%
pip install python-binance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
api_key = os.getenv("BINANCE_API_KEY")
api_secret = os.getenv("BINANCE_SECRET_KEY")

# %%
client = Client(api_key, api_secret)

# %%
# bsm = BinanceSocketManager(client)

# %%
# socket = bsm.trade_socket('BTCUSDT')

# %%
# def get_klines_iter(symbol, interval, start, end, limit=5000):
#     df = pd.DataFrame()
#     startDate = end
#     while startDate>start:
#         url = 'https://api.binance.com/api/v3/klines?symbol=' + \
#             symbol + '&interval=' + interval + '&limit='  + str(iteration)
#         if startDate is not None:
#             url += '&endTime=' + str(startDate)
        
#         df2 = pd.read_json(url)
#         df2.columns = ['Opentime', 'Open', 'High', 'Low', 'Close', 'Volume', 'Closetime', 'Quote asset volume', 'Number of trades','Taker by base', 'Taker buy quote', 'Ignore']
#         df = pd.concat([df2, df], axis=0, ignore_index=True, keys=None)
#         startDate = df.Opentime[0]   
#     df.reset_index(drop=True, inplace=True)    
#     return df

# %%
# get_klines_iter(BTCUSDT, 1M, 2016-01-01, 2021-09-30, 5000)

# %%
# Out:
# Please enter the frequency (1m/5m/30m/.../1h/6h/1d/ :   6h

# %%
pd.DataFrame(client.get_historical_klines('BTCUSDT', '1m', '30m ago UTC'))
# Out:
#                0               1               2               3   \
# 0   1633746360000  54046.26000000  54097.34000000  54046.21000000
# 1   1633746420000  54075.50000000  54087.65000000  54009.82000000
# 2   1633746480000  54017.72000000  54053.59000000  54003.00000000
# 3   1633746540000  54036.64000000  54079.99000000  54036.63000000
# 4   1633746600000  54056.19000000  54099.55000000  54041.80000000
# 5   1633746660000  54092.37000000  54128.53000000  54090.71000000
# 6   1633746720000  54105.27000000  54128.49000000  54091.44000000
# 7   1633746780000  54117.26000000  54141.06000000  54112.70000000
# 8   1633746840000  54129.17000000  54189.89000000  54129.16000000
# 9   1633746900000  54157.00000000  54189.89000000  54147.33000000
# 10  1633746960000  54189.88000000  54189.88000000  54150.72000000
# 11  1633747020000  54175.01000000  54175.01000000  54136.00000000
# 12  1633747080000  54136.00000000  54143.72000000  54121.66000000
# ...

# %%
def getminutedata(symbol, interval, lookback):
    frame = pd.DataFrame(client.get_historical_klines(symbol, interval, lookback+' min ago UTC'))
    frame = frame.iloc[:,:6]
    frame.columns = ['Time','Open','High','Low','Close','Volume']
    frame = frame.set_index('Time')
    frame.index = pd.to_datetime(frame.index, unit='ms')
    frame = frame.astype(float)
    return frame

# %%
getminutedata('BTCUSDT', '1m', '30m')
# Out:
#                          Open      High       Low     Close    Volume
# Time
# 2021-10-09 02:26:00  54046.26  54097.34  54046.21  54075.51   7.23772
# 2021-10-09 02:27:00  54075.50  54087.65  54009.82  54017.73   6.37317
# 2021-10-09 02:28:00  54017.72  54053.59  54003.00  54036.64   6.11427
# 2021-10-09 02:29:00  54036.64  54079.99  54036.63  54056.19  10.45265
# 2021-10-09 02:30:00  54056.19  54099.55  54041.80  54092.37  13.99879
# 2021-10-09 02:31:00  54092.37  54128.53  54090.71  54105.28  21.71830
# 2021-10-09 02:32:00  54105.27  54128.49  54091.44  54117.26  15.16520
# 2021-10-09 02:33:00  54117.26  54141.06  54112.70  54129.17   6.13467
# 2021-10-09 02:34:00  54129.17  54189.89  54129.16  54157.01  36.14236
# 2021-10-09 02:35:00  54157.00  54189.89  54147.33  54189.88  10.19261
# 2021-10-09 02:36:00  54189.88  54189.88  54150.72  54175.01  12.10415
# 2021-10-09 02:37:00  54175.01  54175.01  54136.00  54136.01   8.15250
# ...

# %%
test = getminutedata('BTCUSDT', '1m', '30')

# %%
from pathlib import Path
# btcusdt_hist = pd.DataFrame(
#     data = test
# )

# Path = ("../Julia/btcusdt_hist.csv")
# btcusdt_hist.to_csv(Path)

# %%
btcusdt_daily = test

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-cfa0183e20a6> in <module>
# ----> 1 btcusdt_hist = pd.DataFrame("../Julia/btcusdt_hist.csv")
#       2 btcusdt_hist
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527         else:
#     528             if index is None or columns is None:
# --> 529                 raise ValueError("DataFrame constructor not properly called!")
#     530
#     531             if not dtype:
#
# ValueError: DataFrame constructor not properly called!

# %%
newdata = btcusdt_hist.append(btcusdt_daily).drop_duplicates()

newdata.to_csv("../Julia/btcusdt_minute.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-40cc80e91e39> in <module>
# ----> 1 newdata = btcusdt_hist.append(btcusdt_daily).drop_duplicates()
#       2
#       3 newdata.to_csv("../Julia/btcusdt_hist.csv")
#
# AttributeError: 'str' object has no attribute 'append'

# %%
# btcusdt_hist.append(btcusdt_daily).drop_duplicates()

# btcusdt_hist.to_csv(Path)

# %%
# btcusdt_hist = pd.DataFrame(
#     btcusdt_daily
# )

# Path = ("../Julia/btcusdt_daily.csv")
# btcusdt_daily.to_csv(Path)

# %%
test.Open.plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
"""  Buy if asset fell by more then 0.2% within the last 30 min (Calculate volatility in a minute for parameter)

     Sell if asset rises by more then 0.15% or falls further by 0.15% 
     (Break even point where you are exceeding the trading fees and actually making a profit)
 """

# %%
def strategytest(symbol, qty, entried=False):
    df = getminutedata(symbol, '1m', '30m')
    cumulret = (df.Open.pct_change() +1).cumprod() - 1
    if not entried:
        if cumulret[-1] < -0.002:
            order = client.create_order(symbol=symbol,
                                        side='BUY', type='MARKET',
                                        quantity=qty)
            print(order)
            entried=True
        else:
            print('No Trade has been executed')
    if entried:
        while True:
            df = getminutedata(symbol, '1m', '30m')
            sincebuy = df.loc[df.index > pd.to_datetime(
            order['transactTime'], unit='ms')]
            if len(sincebuy) > 0:
                sincebuyret = (sincebuy.Open.pct_change() +1).cumprod() - 1
                if sincebuyret[-1] > 0.0015 or sincebuyret[-1] < -0.015:
                    order = client.create_order(symbol=symbol,
                                        side='SELL', type='MARKET',
                                        quantity=qty)
                    print(order)
                    break

# %%
strategytest('BTCUSDT',0.00)
# Out:
# No Trade has been executed
